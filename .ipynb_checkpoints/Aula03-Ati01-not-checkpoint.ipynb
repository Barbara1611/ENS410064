# %% [markdown]
# ## AULA 03 - ATIVIDADE 01

# %%
import pandas as pd

# Pegando os dados
df = pd.read_csv (r'C:\Users\55489\Documents\ENS410064\dados\brutosAti01\dataQualidade.csv')
df
# Out:
#            date site  depth_m  Wat_temp_Celcius    DO_sat%     DO_mgL   pH  \
# 0      2011/3/9  YRZ      0.5          0.042750  94.550000  13.773000  7.7
# 1     2011/3/30  YRZ      0.5          1.822200  93.555000  12.970500  7.3
# 2     2011/4/19  YRZ      0.5          5.483850  99.045000  12.465500  7.4
# 3      2011/5/3  YRZ      0.5          5.018400  83.480000  10.631000  7.4
# 4     2011/5/18  YRZ      0.5          9.204350  91.505000  10.502000  7.7
# ..          ...  ...      ...               ...        ...        ...  ...
# 578  2021/10/19  YHZ      0.5          7.702113  93.739634  11.141295  7.6
# 579   2021/11/2  YHZ      0.5          7.498940  89.503738  10.689767  7.2
# 580  2021/11/16  YHZ      0.5          4.810213  95.125858  12.161947  7.2
# 581  2021/11/30  YHZ      0.5          1.633006  94.562307  13.152066  7.4
# 582  2021/12/14  YHZ      0.5          3.390355  98.427397  13.063240  7.6
#
# ...

# %%
df.head()
# Out:
#         date site  depth_m  Wat_temp_Celcius  DO_sat%   DO_mgL   pH  DOC_mgL  \
# 0   2011/3/9  YRZ      0.5           0.04275   94.550  13.7730  7.7     1.86
# 1  2011/3/30  YRZ      0.5           1.82220   93.555  12.9705  7.3     2.23
# 2  2011/4/19  YRZ      0.5           5.48385   99.045  12.4655  7.4     2.09
# 3   2011/5/3  YRZ      0.5           5.01840   83.480  10.6310  7.4     2.46
# 4  2011/5/18  YRZ      0.5           9.20435   91.505  10.5020  7.7     2.33
#
#    POC_mgL  TP_mgL  DP_mgL  SRP_mgL  TN_mgL  NH4_N_mgL  NO3_N_mgL  PN_mgL  \
# 0      0.4   0.013   0.010    0.008     NaN      0.014      0.797    0.09
# 1      0.3   0.011   0.007    0.004   0.800      0.019      0.620    0.38
# 2      0.6   0.020   0.006    0.003   0.780      0.029      0.480    0.10
# 3      0.5   0.019   0.010    0.004   0.687      0.028      0.276    0.10
# 4      0.7   0.032   0.016    0.005   0.770      0.024      0.412    0.70
#
#    Si_mgL  Chla_lab_mgL  Chla_CTDprobe_mgL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               583 non-null    object
#  1   site               583 non-null    object
#  2   depth_m            583 non-null    float64
#  3   Wat_temp_Celcius   437 non-null    float64
#  4   DO_sat%            437 non-null    float64
#  5   DO_mgL             437 non-null    float64
#  6   pH                 491 non-null    float64
#  7   DOC_mgL            536 non-null    float64
#  8   POC_mgL            531 non-null    float64
#  9   TP_mgL             530 non-null    float64
#  10  DP_mgL             484 non-null    float64
#  11  SRP_mgL            530 non-null    float64
#  12  TN_mgL             364 non-null    float64
#  13  NH4_N_mgL          531 non-null    float64
#  14  NO3_N_mgL          531 non-null    float64
# ...

# %%
df['date'] = df['date'].apply(lambda x: str(x).replace("/","-"))
df['date']
# Out:
# 0        2011-3-9
# 1       2011-3-30
# 2       2011-4-19
# 3        2011-5-3
# 4       2011-5-18
#           ...
# 578    2021-10-19
# 579     2021-11-2
# 580    2021-11-16
# 581    2021-11-30
# 582    2021-12-14
# Name: date, Length: 583, dtype: object

# %%
tstamp = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               583 non-null    object
#  1   site               583 non-null    object
#  2   depth_m            583 non-null    float64
#  3   Wat_temp_Celcius   437 non-null    float64
#  4   DO_sat%            437 non-null    float64
#  5   DO_mgL             437 non-null    float64
#  6   pH                 491 non-null    float64
#  7   DOC_mgL            536 non-null    float64
#  8   POC_mgL            531 non-null    float64
#  9   TP_mgL             530 non-null    float64
#  10  DP_mgL             484 non-null    float64
#  11  SRP_mgL            530 non-null    float64
#  12  TN_mgL             364 non-null    float64
#  13  NH4_N_mgL          531 non-null    float64
#  14  NO3_N_mgL          531 non-null    float64
# ...

# %%
df['DOC_mgL'].plot()
df['pH'].plot()
# Out:
# <Axes: >

# %%
## Tentativa de converter para datetime 
# df['nova_data'] = pd.to_datetime(df['date'].str.title(),format='%Y/%b/%d')

# %%
#df['date'] = pd.to_datetime64(df['date'].str.title(),format='%Y%b%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               583 non-null    object
#  1   site               583 non-null    object
#  2   depth_m            583 non-null    float64
#  3   Wat_temp_Celcius   437 non-null    float64
#  4   DO_sat%            437 non-null    float64
#  5   DO_mgL             437 non-null    float64
#  6   pH                 491 non-null    float64
#  7   DOC_mgL            536 non-null    float64
#  8   POC_mgL            531 non-null    float64
#  9   TP_mgL             530 non-null    float64
#  10  DP_mgL             484 non-null    float64
#  11  SRP_mgL            530 non-null    float64
#  12  TN_mgL             364 non-null    float64
#  13  NH4_N_mgL          531 non-null    float64
#  14  NO3_N_mgL          531 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(df['DOC_mgL'])
ax[1].plot(df['pH'])
#ax[2].plot(data[:,1])
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
